# %% [markdown]
# <a href="https://colab.research.google.com/github/sonagidevelop/-Python-/blob/main/tsla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance

# %%
import yfinance as yf

tsla = yf.download('TSLA',start = '2020-08-01')


((((tsla['Close']) - 292) / 292) * 100).plot()
# Out:
# [*********************100%***********************]  1 of 1 completed
